-- %%
CREATE TABLE EmployeeSales (
    emp_id VARCHAR(10),
    emp_name VARCHAR(50),
    sale_amount INT,
    dept VARCHAR(50),
    sale_date DATE
);

-- %%
INSERT INTO EmployeeSales (emp_id, emp_name, sale_amount, dept, sale_date)
VALUES 
('E101', 'Ankit', 5000, 'Fashion', '2023-10-01'),
('E102', 'Priya', 8000, 'Fashion', '2023-10-01'),
('E103', 'Ravi', 7000, 'Electronics', '2023-10-02'),
('E101', 'Ankit', 6000, 'Fashion', '2023-10-03');

-- %%
SELECT * FROM employeesales;

-- %%
SELECT 
es.emp_name,es.dept,es.sale_amount, 
dense_rank() over (partition by dept order by sale_amount desc) as rank
from employeesales AS es

-- %%
SELECT 
es.emp_name,es.sale_date,es.sale_amount,
sum(sale_amount) over (partition by emp_name order by sale_date ) as rank
from employeesales AS es
